# %%
# Goal: Create a Tkinter application that stores and displays names and phone numbers.
# 1.Create two Entry widgets, one for the Name and another for the Phone Number. 함
# 2.Add a button labeled "Add Contact" that, when clicked, appends the entered data to a Listbox.
# 3.Add another button labeled "Clear Fields" that clears both Entry widgets. 
# 4.Use a Label at the top titled "Address Book". 함
# 5.(Optional) Add a Delete button that removes the selected contact from the Listbox.

import tkinter as tk
from tkinter import messagebox

def Add_Contact():
    name=entry_name.get()
    phone=entry_phone.get()
   # result = add_numbers(a, b)
    messagebox.showinfo("Welcome", f"Welcome {name} 님")

def Clear_Fields():
    entry_name.delete(0, "end")
    entry_phone.delete(0, "end")

#def remove():
    #selected=

# 윈도우 설정
root = tk.Tk()
root.title("Address Book")
root.geometry("400x300")

label_name = tk.Label(root, text="Name")
label_name.grid(row=0, column=0, padx=5, pady=5)

label_phone = tk.Label(root, text="Phone number")
label_phone.grid(row=1, column=0, padx=5, pady=5)

# 입력 필드
entry_name = tk.Entry(root)
entry_name.grid(row=0, column=1, padx=5, pady=5)

# 입력 필드
entry_phone = tk.Entry(root)
entry_phone.grid(row=1, column=1,padx=10, pady=10)

# 변환 버튼
convert_btn = tk.Button(root, text="Add Contact", command=Add_Contact)
convert_btn.grid(row=2, column=1, padx=5, pady=5)

clear_btn = tk.Button(root, text="Clear Fields", command=Clear_Fields)
clear_btn.grid(row=3, column=1, padx=5, pady=5)

#delete_btn = tk.Button(root, text="remove", command=remove)
#delete_btn.grid(row=4, column=0, padx=5, pady=5)

# 결과 출력 레이블
result_label = tk.Label(root, text="Enter a name and phone number")
result_label.grid(row=5, column=1, padx=5, pady=5)

# 실행
root.mainloop()

# %%
# Goal: Build a Tkinter app that converts temperatures from 
# Celsius to Fahrenheit.
# 1.Create an Entry widget for the user to input Celsius.
# 2.Add a "Convert" button that calculates Fahrenheit using the 
# formula F = (C * 9/5) + 32.
# 3.Show the result in a Label below the button.
# 4.Change the window title to "Temperature Converter".
# 5.(Optional) Add another button or function to convert Fahrenheit back to Celsius


import tkinter as tk

def Celsius_to_Fahrenheit():
    try:
        C = float(entry.get())
        F = (C * 9/5) + 32
        result_label.config(text=f"{F:.2f} °F")
    except ValueError:
        result_label.config(text="Invalid Input")

def Fahrenheit_to_Celsius():
    try:
        F = float(entry.get())
        C = (F - 32) * 5/9
        result_label.config(text=f"{C:.2f} °C")
    except ValueError:
        result_label.config(text="Invalid Input")

# 윈도우 설정
root = tk.Tk()
root.title("Temperature Converter")
root.geometry("400x200")

# 입력 필드
entry = tk.Entry(root)
entry.pack(pady=10)

# 변환 버튼
convert_btn = tk.Button(root, text="Convert to Fahrenheit", command=Celsius_to_Fahrenheit)
convert_btn.pack()

convert_back_btn = tk.Button(root, text="Convert to Celsius", command=Fahrenheit_to_Celsius)
convert_back_btn.pack()

# 결과 출력 레이블
result_label = tk.Label(root, text="Enter a value and convert")
result_label.pack(pady=10)

# 실행
root.mainloop()
